# %%
import sqlite3
con = sqlite3.connect('/content/my_coffee_2.db')
cur = con.cursor()

# %%
import pandas as pd
df = pd.read_sql('SELECT * FROM my_coffee_2', con)

# %%
df.head()
# Out:
#          date                 datetime cash_type                 card  money  \
# 0  2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
#
#       cofee_name
# 0          Latte
# 1  Hot Chocolate
# 2  Hot Chocolate
# 3      Americano
# 4          Latte

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.lineplot(data = df, x = 'date', y = 'money')
# Out:
# <Axes: xlabel='date', ylabel='money'>

# %%
sns.histplot(data = df, x = 'cash_type')
# Out:
# <Axes: xlabel='cash_type', ylabel='Count'>

# %%
sns.histplot(data = df, y = 'cofee_name')
# Out:
# <Axes: xlabel='Count', ylabel='cofee_name'>

# %%
sns.histplot(data = df, x = 'money', y = 'cofee_name')
# Out:
# <Axes: xlabel='money', ylabel='cofee_name'>

# %%
#Подсчитаем сумму полученную с Латте
cur.execute(" SELECT SUM(money) FROM my_coffee_2 WHERE cofee_name = 'Latte' ")
Latte_amount_of_money = cur.fetchone()
print('Общая сумма чеков за Латте:',Latte_amount_of_money)
# Out:
# Общая сумма чеков за Латте: (7696.340000000009,)

# %%
#Подсчитаем сумму полученную с продаж Горячего шоколада
cur.execute(" SELECT SUM(money) FROM my_coffee_2 WHERE cofee_name = 'Hot Chocolate' ")
Hot_Chocolate_amount_of_money = cur.fetchone()
print('Общая сумма чеков за горячий шоколад:', Hot_Chocolate_amount_of_money)
# Out:
# Общая сумма чеков за горячий шоколад: (2680.0200000000004,)

# %%
#Подсчитаем сумму полученную с продаж Американо
cur.execute(" SELECT SUM(money) FROM my_coffee_2 WHERE cofee_name = 'Americano' ")
Americano_amount_of_money = cur.fetchone()
print('Общая сумма чеков за Американо:', Americano_amount_of_money)
# Out:
# Общая сумма чеков за Американо: (4092.0600000000063,)

# %%
#Подсчитаем сумму полученную с продаж Американо с молоком
cur.execute(" SELECT SUM(money) FROM my_coffee_2 WHERE cofee_name = 'Americano with Milk' ")
Americano_with_milk_amount_of_money = cur.fetchone()
print('Общая сумма чеков за Американо с молоком:', Americano_with_milk_amount_of_money)
# Out:
# Общая сумма чеков за Американо с молоком: (7457.219999999983,)

# %%
#Подсчитаем сумму полученную с продаж Кокао
cur.execute(" SELECT SUM(money) FROM my_coffee_2 WHERE cofee_name = 'Cocoa' ")
Cocoa_amount_of_money = cur.fetchone()
print('Общая сумма чеков за кокао:', Cocoa_amount_of_money)
# Out:
# Общая сумма чеков за кокао: (1066.2000000000003,)

# %%
#Подсчитаем сумму полученную с продаж Кортадо
cur.execute(" SELECT SUM(money) FROM my_coffee_2 WHERE cofee_name = 'Cortado' ")
Cortado_amount_of_money = cur.fetchone()
print('Общая сумма чеков за Кордато:', Cortado_amount_of_money)
# Out:
# Общая сумма чеков за Кордато: (2445.820000000003,)

# %%
#Подсчитаем сумму полученную с продаж Эспрессо
cur.execute(" SELECT SUM(money) FROM my_coffee_2 WHERE cofee_name = 'Espresso' ")
Espresso_amount_of_money = cur.fetchone()
print('Общая сумма чеков за Эспрессо:', Espresso_amount_of_money)
# Out:
# Общая сумма чеков за Эспрессо: (919.4199999999996,)

# %%
#Подсчитаем сумму полученную с продаж Капучино
cur.execute(" SELECT SUM(money) FROM my_coffee_2 WHERE cofee_name = 'Cappuccino' ")
Cappuccino_amount_of_money = cur.fetchone()
print('Общая сумма чеков за Капучино:', Cappuccino_amount_of_money)
# Out:
# Общая сумма чеков за Капучино: (6709.560000000005,)

# %%
coffee_name = ['Латте', 'Горячий шоколад', 'Американо', 'Американо с молоком','Кокао', 'Кордато', 'Эспрессо', 'Капучино']
amount_of_money = [Latte_amount_of_money, Hot_Chocolate_amount_of_money, Americano_amount_of_money, Americano_with_milk_amount_of_money, Cocoa_amount_of_money, Cortado_amount_of_money, Espresso_amount_of_money, Cappuccino_amount_of_money]
amount_of_money = [7696, 2680, 4092, 7457, 1066, 2445, 919, 6709]

# %%
sns.barplot(x = amount_of_money, y = coffee_name)
# Out:
# <Axes: >
